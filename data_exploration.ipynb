# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv('Teste.csv')

# %%
df
# Out:
#          agente associacao data_criacao   data_transferencia  \
# 0           NaN  EMPRESA A   01/01/2023                  NaN
# 1        AMANDA  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# 2        AMANDA  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# 3        CINTIA  EMPRESA A   01/01/2023  06/01/2023 00:00:00
# 4        DENISE  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# ...         ...        ...          ...                  ...
# 4995     TÁLITA  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4996     TÁLITA  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4997     VIDROS  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4998     VIDROS  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4999  WANDERSON  EMPRESA A   31/01/2023  31/01/2023 00:00:00
#
#          data_finalizacao      protocolo        telefone  \
# 0     01/01/2023 00:00:00   101236364632  551191279-xxxx
# 1     01/01/2023 00:00:00   101231683509  556698117-xxxx
# 2     01/01/2023 00:00:00   101235784889  556299822-xxxx
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          agente associacao data_criacao   data_transferencia  \
# 0           NaN  EMPRESA A   01/01/2023                  NaN
# 1        AMANDA  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# 2        AMANDA  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# 3        CINTIA  EMPRESA A   01/01/2023  06/01/2023 00:00:00
# 4        DENISE  EMPRESA A   01/01/2023  01/01/2023 00:00:00
# ...         ...        ...          ...                  ...
# 4995     TÁLITA  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4996     TÁLITA  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4997     VIDROS  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4998     VIDROS  EMPRESA A   31/01/2023  31/01/2023 00:00:00
# 4999  WANDERSON  EMPRESA A   31/01/2023  31/01/2023 00:00:00
#
#          data_finalizacao      protocolo        telefone  \
# 0     01/01/2023 00:00:00   101236364632  551191279-xxxx
# 1     01/01/2023 00:00:00   101231683509  556698117-xxxx
# ...

# %%
df['Departamento'].unique()
# Out:
# array(['ATENDIMENTO PARA EMPRESA D', 'ASSISTÊNCIA',
#        'ATENDIMENTO PARA EMPRESA A', 'ATENDIMENTO PARA EMPRESA C',
#        'AQUARIO', 'SETOR DE ATENDIMENTO', 'ADMINISTRATIVO',
#        'SETOR DE EVENTOS', 'SETOR DE MONITORAMENTO', 'SETOR COMERCIAL',
#        'SETOR DE COBRANÇA'], dtype=object)

# %%
atend = ['ATENDIMENTO PARA EMPRESA D',
       'ATENDIMENTO PARA EMPRESA A', 'ATENDIMENTO PARA EMPRESA C', 'SETOR DE ATENDIMENTO']

# %%
df.loc[ df['Departamento'] in atend,'Atendimento ?'] = 'Atendimento'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19404\4287527890.py in ?()
# ----> 1 df.loc[ df['Departamento'] in atend,'Atendimento ?'] = 'Atendimento'
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
